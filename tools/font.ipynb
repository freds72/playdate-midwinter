# %%
data = [[6," "],[22,"%ⒶⒷ🎣✛⬆️➡️⬇️⬅️"],[21,"W@©"],[20,"w™Щ"],[19,"Mm®…æ "],[18,"V#€ÆŒœ"],[17,"GOQUÐĞÒÓÔÖÕŐØÙÚÛÜŰО"],[16,"ABDNPgn&«»ÀÁÂÄÃÅĄÑŃẞðğñńßűАВЄЗИЙЛРЭжфцю"],[15,"CEFHKRSXYkuv023456789~$£ÇĆÈÉÊËĘŁŚŞÞÝŸőþùúûüБҐЕЁКНПСУХЧЬЯвзийъ"],[14,"JLbdehopqrx?+*¢¿“”„èéêëęòóôöõøбґеёєклнопрхчэ"],[13,"Tacfsty-_àáâäãåąçćśşýÿ"],[12,"Z\"/\\ÏŹŻïЇї"],[11,"z1=^ÌÎîłźż"],[10,"j!°<>¡‹›•Íİ"],[9,"Iil()[]{}ìíІі"],[8,";:`‘’‚ı"],[7,".,'·"],[6,"|"]]

charset = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789.,;:?!\"'+-=*%_()[]{}~#&@©®™°^`|/\<>…€$£¢¿¡“”‘’«»‹›„‚·•ÀÁÂÄÃÅĄÆÇĆÐÈÉÊËĘĞÌÍÎÏİŁÑŃÒÓÔÖÕŐØŒŚŞẞÞÙÚÛÜŰÝŸŹŻàáâäãåąæçćðèéêëęğìíîïıłñńòóôöõőøœśşßþùúûüűýÿźżⒶⒷ🎣 ✛⬆️➡️⬇️⬅️"
spaces = {}
for category in data:
  space, chars = category
  for c in chars:
    spaces[c] = space

print("tracking=0")
for c in charset:
  ch = c
  if ch==" ": ch="space"
  print(ch,"\t",spaces[c])
# Out:
# tracking=0
# A 	 16
# B 	 16
# C 	 15
# D 	 16
# E 	 15
# F 	 15
# G 	 17
# H 	 15
# I 	 9
# J 	 14
# K 	 15
# L 	 14
# M 	 19
# N 	 16
# O 	 17
# P 	 16
# Q 	 17
# R 	 15
# S 	 15
# T 	 13
# U 	 17
# V 	 18
# W 	 21
# X 	 15
# Y 	 15
# Z 	 12
# a 	 13
# b 	 14
# c 	 13
# d 	 14
# e 	 14
# f 	 13
# g 	 16
# h 	 14
# i 	 9
# j 	 10
# k 	 15
# l 	 9
# m 	 19
# n 	 16
# o 	 14
# p 	 14
# q 	 14
# r 	 14
# s 	 13
# t 	 13
# u 	 15
# v 	 15
# w 	 20
# x 	 14
# y 	 13
# z 	 11
# 0 	 15
# 1 	 11
# 2 	 15
# 3 	 15
# 4 	 15
# 5 	 15
# 6 	 15
# 7 	 15
# 8 	 15
# 9 	 15
# . 	 7
# , 	 7
# ; 	 8
# : 	 8
# ? 	 14
# ! 	 10
# " 	 12
# ' 	 7
# + 	 14
# - 	 13
# = 	 11
# * 	 14
# % 	 22
# _ 	 13
# ( 	 9
# ) 	 9
# [ 	 9
# ] 	 9
# { 	 9
# } 	 9
# ~ 	 15
# # 	 18
# & 	 16
# @ 	 21
# © 	 21
# ® 	 19
# ™ 	 20
# ° 	 10
# ^ 	 11
# ` 	 8
# | 	 6
# / 	 12
# \ 	 12
# < 	 10
# > 	 10
# … 	 19
# € 	 18
# $ 	 15
# £ 	 15
# ¢ 	 14
# ¿ 	 14
# ¡ 	 10
# “ 	 14
# ” 	 14
# ‘ 	 8
# ’ 	 8
# « 	 16
# » 	 16
# ‹ 	 10
# ...
